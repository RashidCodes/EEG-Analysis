# %% [markdown]
# # Research Methodology (Summary)
#
# <img src="Feature extraction Roadmap.png" >

# %% [markdown]
# # Data Import

# %%
import numpy as np
from scipy.io import loadmat

# %%
# import the data for patient 1
dict_ = loadmat('./Class A train sets/2_EEG200908190811.mat')
dict_.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'BIS', 'x', 'CH2', 'Denoised_x', 'CH2Denoised_x'])

# %% [markdown]
# <br/>

# %% [markdown]
# # Exploration

# %% [markdown]
# We'll be using the **CH2Denoised_x** and **BIS** columns

# %%
import matplotlib.pyplot as plt

data = dict_.get('CH2Denoised_x')
data = np.ravel(data)

# %%
bis = dict_.get('BIS')
bis = np.ravel(bis)

# %%
# Patient's BIS values throughout the surgery
fig = plt.figure(figsize=(10, 8))
plt.plot(bis)
plt.xlabel("Sample Number")
plt.ylabel("BIS Index")
plt.title("Patients BIS Index throughout the surgery")
plt.show()

# %% [markdown]
# <br/>
#
# The EEG signal was sampled at a frequency of $128Hz$. So, each BIS value was calculated using $128$ samples of the EEG signal.

# %% [markdown]
# <br/>

# %% [markdown]
# ## The Awake state of Patient 1.

# %%
# sampling rate
fs = 128

# The awake state
awake_idx = np.where((bis <=100) & (bis >= 80))
awake = bis[awake_idx]

# The corresponding EEG in the awake state
eeg_sample = data[:10*fs]

# %%
# Patient's BIS values in the awake state
fig = plt.figure(figsize=(10, 8))
plt.plot(awake)
plt.xlabel("Sample Number")
plt.ylabel("BIS Index")
plt.title("Patients BIS Index in the Awake state")
# Out:
# Text(0.5, 1.0, 'Patients BIS Index in the Awake state')

# %%
# Plot the sample
fig = plt.figure(figsize=(10, 8))
plt.plot(eeg_sample)
plt.xlabel("Sample Number")
plt.ylabel("Voltage ($\mu$V)")
plt.title("Patient's EEG signal in the Awake state")
plt.show()

# %% [markdown]
# <br/>

# %% [markdown]
# # Spectral Analysis (DFT)

# %%
# real frequencies
fft_values = np.absolute(np.fft.rfft(eeg_sample))

fft_freq = np.fft.rfftfreq(len(eeg_sample), 1.0/fs)

# Plot the fourier transform
figure = plt.figure(figsize=(10, 8))
plt.plot(fft_freq, fft_values)
plt.ylabel("Amplitude")
plt.xlabel("Frequencies")
plt.title("Fourier transform of the EEG Sample")
plt.show()

# %%
# Analysing the bands
eeg_bands = {'Delta': (0, 4),
             'Theta': (4, 8),
             'Alpha': (8, 12),
             'Beta': (12, 30),
             'Gamma': (30, 45)}

eeg_band_fft = dict()

for band in eeg_bands.keys():
    freq_idx = np.where((fft_freq >= eeg_bands[band][0]) & (fft_freq <= eeg_bands[band][1]))
    
    # sum the amplitudes of the bands
    eeg_band_fft[band] = fft_values[freq_idx]

# %%
bands = [band for band in eeg_band_fft.keys()]
mean_amplitude = [np.mean(amp) for amp in eeg_band_fft.values()]

# %%
figure = plt.figure(figsize=(10, 8))
plt.bar(bands, mean_amplitude, width=0.5)
plt.xlabel("Frequency bands")
plt.ylabel("Amplitude")
plt.title("Amplitude of frequency bands")
plt.show()

# %% [markdown]
# ## Calculation of Parameters: The Delta Band

# %%
delta = eeg_band_fft['Delta']

# %%
delta.shape
# Out:
# (41,)

# %%
ant.sample_entropy?

# %% [markdown]
# ### Sample Entropy

# %%
import antropy as ant

delta_sampen = ant.sample_entropy(delta)
delta_sampen
# Out:
# 0.13005312824819779

# %% [markdown]
# ### 25th percentile

# %%
delta_25 = np.percentile(delta, 25)
delta_25
# Out:
# 1213.8589648022507

# %% [markdown]
# ### Standard Deviation

# %%
delta_var = np.std(delta)
delta_var
# Out:
# 3527.605289903228

# %%
gaussians.py_func?
# Out:
# Object `gaussians.py_func` not found.

# %%
x = np.random.rand(5, 5)

# %%
x[::2]
# Out:
# array([[0.83890816, 0.79887431, 0.53790959, 0.81600726, 0.4128419 ],
#        [0.64454936, 0.61547465, 0.83117764, 0.27935949, 0.81816759],
#        [0.74681505, 0.99838623, 0.91135123, 0.77533911, 0.94079933]])

# %%
x
# Out:
# array([[0.83890816, 0.79887431, 0.53790959, 0.81600726, 0.4128419 ],
#        [0.51721179, 0.37103122, 0.05500967, 0.32003865, 0.57129567],
#        [0.64454936, 0.61547465, 0.83117764, 0.27935949, 0.81816759],
#        [0.8286627 , 0.20357097, 0.81118738, 0.08233872, 0.49887237],
#        [0.74681505, 0.99838623, 0.91135123, 0.77533911, 0.94079933]])

# %%
a = [2, 2, 5, 2, 6, 2, 6]

a[::2]
# Out:
# [2, 5, 6, 6]
